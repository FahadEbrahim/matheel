# %% [markdown]
# # 04 Gradio App
#
# Install Matheel with all optional extras and launch the Gradio app in Colab.

# %%
# %%bash
# set -euo pipefail
# MATHEEL_REF="main"
# pip uninstall -y torchvision || true
# rm -rf /content/matheel
# git clone https://github.com/FahadEbrahim/matheel.git /content/matheel
# cd /content/matheel
# git checkout "$MATHEEL_REF"
# pip install -e ".[all]"
# echo "Matheel installed from $MATHEEL_REF. If Colab asks, restart the runtime once before launching the app."

# %%
import platform
import sys

print("Python:", sys.version)
print("Platform:", platform.platform())
print("CUDA available:", end=" ")
try:
    import torch
    print(torch.cuda.is_available())
except Exception as exc:
    print(f"unknown ({exc})")

# %%
# %cd /content/matheel

import os

os.environ["GRADIO_SERVER_NAME"] = "0.0.0.0"
os.environ["MPLCONFIGDIR"] = "/tmp/mplconfig"

from gradio_app.app import demo

demo.launch(share=True, show_error=True, debug=True)

# %% [markdown]
# If the launch cell shows a public Gradio link, open that link. The first model interaction may be slow while dependencies and models warm up.
